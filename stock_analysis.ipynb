# %% [markdown]
# ### Which sector has the highest `market capitalization`
#
# Side Note: Market capitalization, or market cap, is the total dollar value of a company’s outstanding shares of stock, calculated by multiplying the current share price by the total number of outstanding shares.

# %%
# %%sql
# SELECT
#     SUM(market_capitalization_rs) AS net_market_capitalization_rs, sector
#     FROM company_list
#     GROUP BY sector
# ORDER BY net_market_capitalization_rs DESC
# Out:
#     net_market_capitalization_rs                        sector
# 0                            NaN              Government Bonds
# 1                   6.678779e+11                    Hydropower
# 2                   6.223126e+11               Commercial Bank
# 3                   4.507150e+11                        Others
# 4                   3.964131e+11                Life Insurance
# 5                   3.643423e+11                  Microfinance
# 6                   3.253813e+11                    Investment
# 7                   2.531858e+11  Manufacturing and Processing
# 8                   2.141280e+11                       Trading
# 9                   2.101053e+11          Corporate Debentures
# 10                  2.028428e+11            Non-Life Insurance
# 11                  1.960619e+11              Development Bank
# 12                  1.379709e+11                Promoter Share
# 13                  7.198857e+10               Hotel & Tourism
# 14                  6.560539e+10                       Finance
# 15                  4.850838e+10                   Mutual Fund
# 16                  9.500000e+08              Preference Share

# %% [markdown]
# ### `Government Bonds` are not a number, inspecting that little more.

# %%
# %%sql
# SELECT COUNT(*) as government_bound_counts
#     FROM company_list
# WHERE sector = 'Government Bonds'
# Out:
#    government_bound_counts
# 0                        2

# %% [markdown]
# ### Company with the top 20 highest `market capitalization`

# %%
# %%sql
# SELECT SUM(market_capitalization_rs) as net_market_capitalization_rs, company
#     FROM company_list
#     WHERE market_capitalization_rs IS NOT NULL
#     GROUP BY company
# ORDER BY net_market_capitalization_rs DESC LIMIT 20;
# Out:
#     net_market_capitalization_rs  \
# 0                   1.970755e+11
# 1                   1.767702e+11
# 2                   1.534140e+11
# 3                   1.181616e+11
# 4                   1.072294e+11
# 5                   8.754238e+10
# 6                   8.629192e+10
# 7                   8.534139e+10
# 8                   7.213982e+10
# 9                   6.557470e+10
# 10                  6.484433e+10
# 11                  5.959440e+10
# 12                  5.611871e+10
# 13                  4.885569e+10
# 14                  4.774178e+10
# 15                  4.655090e+10
# 16                  4.653000e+10
# 17                  4.578201e+10
# 18                  4.477950e+10
# 19                  4.364778e+10
#
#                                               company
# 0                        Bishal Bazar Company Limited
# 1                   Nepal Reinsurance Company Limited
# 2                   Nepal Doorsanchar Company Limited
# 3                            Citizen Investment Trust
# 4    10.25% Global IME Bank Limited Debenture 2080/81
# 5                                Everest Bank Limited
# 6                       Himalayan Reinsurance Limited
# 7                             Global IME Bank Limited
# 8                Nepal Life Insurance Company Limited
# 9   Hydroelectricity Investment and Development Co...
# 10                 Nepal Investment Mega Bank Limited
# 11                  Nepal Infrastructure Bank Limited
# 12                         Laxmi Sunrise Bank Limited
# 13                      Prime Commercial Bank Limited
# 14                            Siddhartha Bank Limited
# 15                                Kumari Bank Limited
# 16           Life Insurance Corporation Nepal Limited
# 17                              NIC Asia Bank Limited
# 18                           Sarbottam Cement Limited
# 19                                Prabhu Bank Limited

# %% [markdown]
# ### Sector with the highest `total_paid_up_capital_rs`
#
# Side Note:- Total Paid-Up Capital (Rs) refers to the actual amount of money a company has received from its shareholders in exchange for shares of stock.

# %%
# %%sql
# SELECT
#     MAX(total_paid_up_capital_rs) as total_paid_up_capital_rs_sector, sector
#     FROM company_list
#     WHERE total_paid_up_capital_rs IS NOT NULL
#     GROUP BY sector
# ORDER BY total_paid_up_capital_rs_sector DESC;
# Out:
#     total_paid_up_capital_rs_sector                        sector
# 0                      103105160000          Corporate Debentures
# 1                       38115852800               Commercial Bank
# 2                       24559813400                    Investment
# 3                       21180000000                    Hydropower
# 4                       18000000000                        Others
# 5                       11514672800                Promoter Share
# 6                        9143237400                Life Insurance
# 7                        8000388900              Development Bank
# 8                        5456808500  Manufacturing and Processing
# 9                        5000000000                   Mutual Fund
# 10                       4312621700                  Microfinance
# 11                       4010000000                       Trading
# 12                       3029334600            Non-Life Insurance
# 13                       3013200000               Hotel & Tourism
# 14                       1351552900                       Finance
# 15                        200000000              Preference Share

# %% [markdown]
# ### Top 30 company with the highest `total_paid_up_capital_rs`

# %%
# %%sql
# SELECT
#     MAX(total_paid_up_capital_rs) as total_paid_up_capital_rs_sector, company, sector
#     FROM company_list
#     WHERE total_paid_up_capital_rs IS NOT NULL
#     GROUP BY company, sector
# ORDER BY total_paid_up_capital_rs_sector DESC LIMIT 30;
# Out:
#     total_paid_up_capital_rs_sector  \
# 0                      103105160000
# 1                       38115852800
# 2                       34128594900
# 3                       26225861300
# 4                       24559813400
# 5                       24346512300
# 6                       23542489900
# 7                       21600000000
# 8                       21180000000
# 9                       19402575900
# 10                      18000000000
# 11                      15507463800
# 12                      14917567000
# 13                      14794479200
# 14                      13721376000
# 15                      13581525600
# 16                      13422187100
# 17                      12086211600
# 18                      11514672800
# 19                      10868000000
# 20                       9143237400
# 21                       9028763300
# 22                       8782397400
# 23                       8000388900
# 24                       6842100000
# 25                       6481712500
# 26                       6075927800
# 27                       6021348600
# 28                       6000000000
# 29                       5500000000
#
#                                               company                sector
# 0    10.25% Global IME Bank Limited Debenture 2080/81  Corporate Debentures
# 1                             Global IME Bank Limited       Commercial Bank
# 2                  Nepal Investment Mega Bank Limited       Commercial Bank
# 3                                 Kumari Bank Limited       Commercial Bank
# 4   Hydroelectricity Investment and Development Co...            Investment
# 5                          Laxmi Sunrise Bank Limited       Commercial Bank
# 6                                 Prabhu Bank Limited       Commercial Bank
# 7                   Nepal Infrastructure Bank Limited            Investment
# 8                  Upper Tamakoshi Hydropower Limited            Hydropower
# 9                       Prime Commercial Bank Limited       Commercial Bank
# 10                  Nepal Doorsanchar Company Limited                Others
# 11                Citizens Bank International Limited       Commercial Bank
# 12                              NIC Asia Bank Limited       Commercial Bank
# 13                            Siddhartha Bank Limited       Commercial Bank
# 14                               Everest Bank Limited       Commercial Bank
# 15                                Sanima Bank Limited       Commercial Bank
# 16                  Nepal Reinsurance Company Limited                Others
# 17                       Machhapuchchhre Bank Limited       Commercial Bank
# 18  Nepal Credit and Commerce Bank Limited Promote...        Promoter Share
# 19                      Himalayan Reinsurance Limited                Others
# 20                   Himalayan Life Insurance Limited        Life Insurance
# 21               Nepal Life Insurance Company Limited        Life Insurance
# 22                Chilime Hydro power Company Limited            Hydropower
# 23                       Muktinath Bikas Bank Limited      Development Bank
# 24             Rasuwagadhi Hydropower Company Limited            Hydropower
# 25                           Citizen Investment Trust            Investment
# 26                          Api Power Company Limited            Hydropower
# 27                          Garima Bikas Bank Limited      Development Bank
# 28       Madhya Bhotekoshi Jalavidyut Company Limited            Hydropower
# 29           Life Insurance Corporation Nepal Limited        Life Insurance

# %% [markdown]
# I### LET'S CHECK FOR THE DATA FROM THE YEAR LESS THAN 1994 (Official trading floor opened in 1994)
#
# We need to drop the data.

# %%
# %%sql
# SELECT date_of_operation, company
#     FROM company_list
#     WHERE date_of_operation < '1994-01-01'
# ORDER BY date_of_operation ASC;
# Out:
# Empty DataFrame
# Columns: [date_of_operation, company]
# Index: []

# %%
# %%sql
# DELETE FROM company_list WHERE date_of_operation < '1994-01-13'
